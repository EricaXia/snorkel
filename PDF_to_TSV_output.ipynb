# %%
import numpy as np
import pandas as pd

# %%
import tika
from tika import parser

# %%
from pathlib import Path

pathlist = Path(r'pdfs_epicenter').glob('**/*.pdf')

dict_list = []
paths_list = []

for i, path in enumerate(pathlist):
    path_in_str = str(path)
    paths_list.append(path)
    parsed = parser.from_file(path_in_str)
    parsed["doc_name"] = "doc_" + str(i)
    dict_list.append(parsed)
# Out:
# 2019-03-31 15:07:49,322 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 2019-03-31 15:07:54,374 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...

# %%
# make csv of paths pointing to PDF file locations
paths_df = pd.DataFrame(paths_list)
paths_df.to_csv('paths.csv', header = False, index = False)

# %%
# 39 docs read in
print(len(dict_list))
# Out:
# 39

# %%
print(dict_list[0]['metadata'])
# Out:
# {'Content-Type': 'application/pdf', 'Creation-Date': '2011-06-11T10:39:17Z', 'Last-Modified': '2011-06-11T10:39:17Z', 'Last-Save-Date': '2011-06-11T10:39:17Z', 'X-Parsed-By': ['org.apache.tika.parser.DefaultParser', 'org.apache.tika.parser.pdf.PDFParser'], 'X-TIKA:parse_time_millis': '1114', 'access_permission:assemble_document': 'true', 'access_permission:can_modify': 'true', 'access_permission:can_print': 'true', 'access_permission:can_print_degraded': 'true', 'access_permission:extract_content': 'true', 'access_permission:extract_for_accessibility': 'true', 'access_permission:fill_in_form': 'true', 'access_permission:modify_annotations': 'true', 'created': '2011-06-11T10:39:17Z', 'date': '2011-06-11T10:39:17Z', 'dc:format': 'application/pdf; version=1.3', 'dc:title': 'untitled', 'dcterms:created': '2011-06-11T10:39:17Z', 'dcterms:modified': '2011-06-11T10:39:17Z', 'meta:creation-date': '2011-06-11T10:39:17Z', 'meta:save-date': '2011-06-11T10:39:17Z', 'modified': '2011-06-11T10:39:
# ...

# %%
# write the file names and documents' contents to a dataframe
file_names = []
contents = []

for doc in dict_list:
    file_names.append(doc['metadata']['resourceName'])
    contents.append(doc['content'])
    
df = pd.DataFrame({'file_name':file_names, 'content': contents})

# %%
# remove newline characs
df.replace(r'\n', ' ', regex = True, inplace = True)
# strip leading whitespace
df['content'] = df['content'].str.lstrip()
# remove other whitespace
df.replace(r'\s\s+', ' ', regex = True, inplace = True)
df.replace(r'\t', ' ', regex = True, inplace = True)

# %%
df
# Out:
#                                             file_name  \
# 0   Achazi-2011-Rodents as Sentinels for the Preva...
# 1   Aguirre-1992-Serologic survey for selected arb...
# 2   Balseiro-2012-Louping ill in goats, Spain, 201...
# 3   Buck-1993-Isolation of St. Louis encephalitis.pdf
# 4   Calisher-2006-Bats_ important reservoir hosts.pdf
# 5   Cigarroa-Toledo-2016-Serologic Evidence of Fla...
# 6   de Thoisy-2009-Dengue infection in neotropical...
# 7   Diaz-2016-Activity Patterns of St. Louis Encep...
# 8   Fajs-2012-Phylogeographic characterization of.pdf
# 9       Hubalek-2012-Tick-borne viruses in Europe.pdf
# 10  Jaaskelainen-2006-Siberian subtype tickborne e...
# 11  Kading-2015-Detection of Entebbe Bat Virus Aft...
# 12  Luis-2013-A comparison of bats and rodents as.pdf
# 13  Machain-William-2013-Serologic evidence of fla...
# 14  Mackenzie-2009-The zoonotic flaviviruses of so...
# 15  Medlin-2016-Serosurvey of Selected Arboviral P...
# ...

# %%
print(df.iloc[0]['content'])
# Out:
# untitled Rodents as Sentinels for the Prevalence of Tick-Borne Encephalitis Virus Katharina Achazi,1,* Daniel Růžek,2,* Oliver Donoso-Mantke,1 Mathias Schlegel,3 Hanan Sheikh Ali,3 Mathias Wenk,4 Jonas Schmidt-Chanasit,5 Lutz Ohlmeyer,6 Ferdinand Rühe,7 Torsten Vor,7 Christian Kiffner,7 René Kallies,1,{ Rainer G. Ulrich,3 and Matthias Niedrig1 Abstract Introduction: Tick-borne encephalitis virus (TBEV) causes one of the most important flavivirus infections of the central nervous system, affecting humans in Europe and Asia. It is mainly transmitted by the bite of an infected tick and circulates among them and their vertebrate hosts. Until now, TBE risk analysis in Germany has been based on the incidence of human cases. Because of an increasing vaccination rate, this approach might be misleading, especially in regions of low virus circulation. Method: To test the suitability of rodents as a surrogate marker for virus spread, laboratory-bred Microtus arvalis voles were experimentall
# ...

# %%
# text clean up: 
# remove "- " from the text

# %%
df.to_csv('pdfs.tsv', sep='\t', header = False, index = False, encoding = 'utf-8')

# %%
## NOTE: edit out extra rows in Excel, then save the tsv file, before reading into Snorkel

# %%
## To do next: merge df with metadata
# 1. Clean up metadata 'file' column so it only has the file names and nothing in front
# 2. left join/merge df with metadata-df

# %%
metadata = pd.read_csv(r'EndnoteLibraryData.txt', sep = '\t', encoding = "cp1252")

# %%
# clean up file column
metadata['file'] = metadata['file'].str[26:]

# %%
metadata = metadata.rename(columns = {'file':'file_name'})

# %%
df2 = df.merge(metadata, how = 'left', on = 'file_name')

# %%
# final dataframe of file title, file content, and metadata info all in one table
df2
# Out:
#                                             file_name  \
# 0   Achazi-2011-Rodents as Sentinels for the Preva...
# 1   Aguirre-1992-Serologic survey for selected arb...
# 2   Balseiro-2012-Louping ill in goats, Spain, 201...
# 3   Buck-1993-Isolation of St. Louis encephalitis.pdf
# 4   Calisher-2006-Bats_ important reservoir hosts.pdf
# 5   Cigarroa-Toledo-2016-Serologic Evidence of Fla...
# 6   de Thoisy-2009-Dengue infection in neotropical...
# 7   Diaz-2016-Activity Patterns of St. Louis Encep...
# 8   Fajs-2012-Phylogeographic characterization of.pdf
# 9       Hubalek-2012-Tick-borne viruses in Europe.pdf
# 10  Jaaskelainen-2006-Siberian subtype tickborne e...
# 11  Kading-2015-Detection of Entebbe Bat Virus Aft...
# 12  Luis-2013-A comparison of bats and rodents as.pdf
# 13  Machain-William-2013-Serologic evidence of fla...
# 14  Mackenzie-2009-The zoonotic flaviviruses of so...
# 15  Medlin-2016-Serosurvey of Selected Arboviral P...
# ...

# %%
df2.to_csv('metadata.tsv', sep='\t', header = True, index = False, encoding = 'utf-8')

# %% [markdown]
# ## Extracting more info from the text (eg: virus abbreviations)

# %%
import re
example = "hello 2131242 ffgg (TBEV) f fdr (ABCB) fsdr"
match = re.findall("\([a-zA-Z]{2,6}?\)", example)
print(match)
# Out:
# ['(TBEV)', '(ABCB)']

# %%
matches = df2['content'].str.findall("\([A-Z]{3,4}?\)").tolist()
virus_abbrev = []
def removeNestings(l): 
    for i in l: 
        if type(i) == list: 
            reemovNestings(i) 
        else: 
            virus_abbrev.append(i) 
  
removeNestings(matches)
virus_abbrev = list(set(virus_abbrev))

# %%
virus_abbrev_series = pd.Series(virus_abbrev)

# %%
virus_abbrev_series.to_csv('virus_abbrev.csv', sep = ",", index = False, header = False)

# %%
no_paren = virus_abbrev_series.str.replace("\(|\)", "")
no_paren.drop(no_paren[no_paren.str.contains('MAY$')].index, inplace=True)
no_paren
# Out:
# 0      RSSE
# 1       MCP
# 2       MEV
# 3      TDMV
# 4       ZTV
# 5      FSME
# 6      MRCA
# 7       EIA
# 8      KOUV
# 9      IUCN
# 10     BAHV
# 11     JUTV
# 12      HPD
# 13     UTIV
# 14     MTRV
# 15     ALKV
# 16     UNAM
# 17     AAHL
# 18      PRN
# 19     FUAS
# 20     MAYV
# 21      KUN
# 22      NGS
# 23     ASFV
# 24     SOKV
# 25      TSE
# 26     OKHV
# 27     BAUV
# 28     NCBI
# 29     EYAV
#        ...
# 127    PRNT
# 128    VEEV
# 129    BHAV
# 130     CSF
# 131    WTBE
# 132    SAHV
# 133     ABI
# 134    ABLV
# 135    MEGA
# 136     SLE
# 137    CXFV
# 138    SOLV
# 139    TYUV
# 140     EHD
# 141     ESS
# 142    CPCV
# 143    MYKV
# 144    DHOV
# 145    UVRI
# 146     RGV
# 147    CEEV
# 148     TST
# 149     TMB
# 150     PTV
# 151     CVL
# 152    DEPC
# 153     CTF
# 154     LCV
# 155     PBS
# 156    KUNV
# Length: 156, dtype: object

# %%
no_paren.to_csv("virus_abbrev_noparen.csv", header=False, index=False)
